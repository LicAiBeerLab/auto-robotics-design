# %%
import sympy as sp

def point_function():
    x, y, x_1, y_1,  l_1, l_2, l_3, l_4 = sp.symbols('x y x_1 y_1 l_1 l_2 l_3 l_4')
    x_e, y_e = 0 , -1
    # Step 2: Define the equations
    eq1 = x**2 + y**2 -l_1**2
    eq2 = (x_e-x)**2+(y_e-y)**2 - l_2**2
    eq3 = x_1**2 + y_1**2 -l_3**2
    eq4 = (x_1-x+0.5*(x_e-x))**2 + (y_1-y+0.5*(y_e-y))**2 - l_4**2

    # Step 3: Solve the system of equations
    solutions = sp.solve((eq1, eq2,eq3, eq4), (x, y, x_1, y_1))

    # Step 5: Display the real solutions
    return solutions

# %%
solution = point_function()
solution
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 solution = point_function()
#       2 solution
#
# Cell In[5], line 13, in point_function()
#      10 eq4 = (x_1-x+0.5*(x_e-x))**2 + (y_1-y+0.5*(y_e-y))**2 - l_4**2
#      12 # Step 3: Solve the system of equations
# ---> 13 solutions = sp.solve((eq1, eq2,eq3, eq4), (x, y, x_1, y_1))
#      15 # Step 5: Display the real solutions
#      16 return solutions
#
# File d:\Anaconda\envs\j_moves\lib\site-packages\sympy\solvers\solvers.py:1147, in solve(f, *symbols, **flags)
#    1145         solution = _solve(f[0], *symbols, **flags)
#    1146 else:
# -> 1147     linear, solution = _solve_system(f, symbols, **flags)
#    1148 assert type(solution) is list
#    1149 assert not solution or type(solution[0]) is dict, solution
#
# ...

# %%
import numpy as np

# Define the range for x and y coordinates
x_range = np.linspace(-3, 3, 20)  # 10 points from -5 to 5
y_range = np.linspace(-3, 3, 20)    # 6 points from -3 to 3

# Create the grid
X, Y = np.meshgrid(x_range, y_range)
Z = np.zeros(X.shape)

for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        counter = 0
        x = X[i, j]
        y = Y[i, j]
        if x**2 
        Z[i, j] = 

print("Z grid (results):")
print(Z)

# %%
import sympy as sp

def point_function():
    x, y, x_e, y_e,  l_1, l_2 = sp.symbols('x y x_e y_e l_1 l_2')
    # Step 2: Define the equations
    eq1 = (x-0.1)**2 + y**2 -l_1**2
    eq2 = (x_e-x)**2+(y_e-y)**2 - l_2**2


    # Step 3: Solve the system of equations
    solutions = sp.solve((eq1, eq2), (x, y))

    # Step 5: Display the real solutions
    return solutions

# %%
solution = point_function()
solution
# Out:
# [(-0.05*(-100.0*l_1**2 + 100.0*l_2**2 - 100.0*x_e**2 - 100.0*y_e**2 + 200.0*y_e*(0.5*y_e*(100.0*l_1**2 - 100.0*l_2**2 + 100.0*x_e**2 - 20.0*x_e + 100.0*y_e**2 + 1.0)/(100.0*x_e**2 - 20.0*x_e + 100.0*y_e**2 + 1.0) - 0.05*sqrt(-(100.0*l_1**2 - 200.0*l_1*l_2 + 100.0*l_2**2 - 100.0*x_e**2 + 20.0*x_e - 100.0*y_e**2 - 1.0)*(100.0*l_1**2 + 200.0*l_1*l_2 + 100.0*l_2**2 - 100.0*x_e**2 + 20.0*x_e - 100.0*y_e**2 - 1.0))*(10.0*x_e - 1.0)/(100.0*x_e**2 - 20.0*x_e + 100.0*y_e**2 + 1.0)) + 1.0)/(10.0*x_e - 1.0),
#   0.5*y_e*(100.0*l_1**2 - 100.0*l_2**2 + 100.0*x_e**2 - 20.0*x_e + 100.0*y_e**2 + 1.0)/(100.0*x_e**2 - 20.0*x_e + 100.0*y_e**2 + 1.0) - 0.05*sqrt(-(100.0*l_1**2 - 200.0*l_1*l_2 + 100.0*l_2**2 - 100.0*x_e**2 + 20.0*x_e - 100.0*y_e**2 - 1.0)*(100.0*l_1**2 + 200.0*l_1*l_2 + 100.0*l_2**2 - 100.0*x_e**2 + 20.0*x_e - 100.0*y_e**2 - 1.0))*(10.0*x_e - 1.0)/(100.0*x_e**2 - 20.0*x_e + 100.0*y_e**2 + 1.0)),
# ...
